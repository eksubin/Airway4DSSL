# %%
import os
import json
import time
import torch
import matplotlib.pyplot as plt

from torch.nn import L1Loss
from monai.utils import set_determinism, first
from monai.networks.nets import ViTAutoEnc
from monai.losses import ContrastiveLoss
from monai.data import DataLoader, Dataset
from monai.config import print_config
from monai.transforms import (
    LoadImaged,
    Compose,
    CropForegroundd,
    CopyItemsd,
    SpatialPadd,
    EnsureChannelFirstd,
    Spacingd,
    OneOf,
    ScaleIntensityRanged,
    RandSpatialCropSamplesd,
    RandCoarseDropoutd,
    RandCoarseShuffled,
)

print_config()
# Out:
# MONAI version: 1.4.dev2414
# Numpy version: 1.26.4
# Pytorch version: 2.2.2+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 5b248f6a0dd29cb9c2a9545f980a88de16a6b753
# MONAI __file__: /home/<username>/virtenvs/SSLUnet/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.2.1
# scikit-image version: 0.22.0
# scipy version: 1.13.0
# Pillow version: 10.3.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: NOT INSTALLED or UNKNOWN VERSION.
# tqdm version: 4.66.2
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.8
# pandas version: NOT INSTALLED or UNKNOWN VERSION.
# einops version: 0.7.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
json_path = os.path.normpath("./split_data.json")
data_root = os.path.normpath("./PKG - CT-Covid19-August2020-V1/")
logdir_path = os.path.normpath("./logs/")

# %%
if os.path.exists(logdir_path) is False:
    os.mkdir(logdir_path)

with open(json_path, "r") as json_f:
    json_data = json.load(json_f)

train_data = json_data["training"]
val_data = json_data["validation"]

for idx, _each_d in enumerate(train_data):
    train_data[idx]["image"] = os.path.join(
        data_root, train_data[idx]["image"])

for idx, _each_d in enumerate(val_data):
    val_data[idx]["image"] = os.path.join(data_root, val_data[idx]["image"])

print("Total Number of Training Data Samples: {}".format(len(train_data)))
print(train_data)
print("#" * 10)
print("Total Number of Validation Data Samples: {}".format(len(val_data)))
print(val_data)
print("#" * 10)

# Set Determinism
set_determinism(seed=123)
# Out:
# Total Number of Training Data Samples: 520
# [{'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0176.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0587.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0467.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0184_1.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0213.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0391.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0256_1.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0236.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0284.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0553.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0077.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0670.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0501.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0687.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0509.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0380.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0193.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0276.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0147.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0498.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0444.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0195.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0577.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0506.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0605.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0290.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0621.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0370.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0409.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0580.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0180_0.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0564.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0185.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0615.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0400.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0266.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0551.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0548.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0567.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0135.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0689.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0595.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0594.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0646.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0297.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0203.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0102.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0366.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0680.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0390.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/d ...
# ##########
# Total Number of Validation Data Samples: 130
# [{'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0650.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0461.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0073.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0512.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0423.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0167_1.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0053.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0074_1.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0515.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0456.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0490.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0618.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0171_0.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0249.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0142.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0101.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0258.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0255.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0140.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0477.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0575.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0518.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0696.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0571.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0310.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0365.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0661.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0156.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0393.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0579.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0009.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0251.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0260.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0407.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0554.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0036.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0361.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0314.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0678.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0546.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0354.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0627.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0686.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0592.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0117.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0232.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0593.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0306.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0698.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/data/volume-covid19-A-0625.nii.gz'}, {'image': 'PKG - CT-Covid19-August2020-V1/d ...
# ##########

# %%
# Define Training Transforms
train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        Spacingd(keys=["image"], pixdim=(2.0, 2.0, 2.0), mode=("bilinear")),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
        SpatialPadd(keys=["image"], spatial_size=(32, 32, 32)),
        RandSpatialCropSamplesd(keys=["image"], roi_size=(
            32, 32, 32), random_size=False, num_samples=2),
        CopyItemsd(keys=["image"], times=2, names=[
                   "gt_image", "image_2"], allow_missing_keys=False),
        OneOf(
            transforms=[
                RandCoarseDropoutd(
                    keys=["image"], prob=1.0, holes=6, spatial_size=5, dropout_holes=True, max_spatial_size=32
                ),
                RandCoarseDropoutd(
                    keys=["image"], prob=1.0, holes=6, spatial_size=20, dropout_holes=False, max_spatial_size=64
                ),
            ]
        ),
        RandCoarseShuffled(keys=["image"], prob=0.8, holes=10, spatial_size=8),
        # Please note that that if image, image_2 are called via the same transform call because of the determinism
        # they will get augmented the exact same way which is not the required case here, hence two calls are made
        OneOf(
            transforms=[
                RandCoarseDropoutd(
                    keys=["image_2"], prob=1.0, holes=6, spatial_size=5, dropout_holes=True, max_spatial_size=32
                ),
                RandCoarseDropoutd(
                    keys=["image_2"], prob=1.0, holes=6, spatial_size=20, dropout_holes=False, max_spatial_size=64
                ),
            ]
        ),
        RandCoarseShuffled(keys=["image_2"], prob=0.8,
                           holes=10, spatial_size=8),
    ]
)


check_ds = Dataset(data=train_data, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image = check_data["image"][0][0]
print(f"image shape: {image.shape}")
# Out:
# /home/erattakulangara/virtenvs/SSLUnet/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)
# image shape: torch.Size([32, 32, 32])

# %%
# Training Config

# Define Network ViT backbone & Loss & Optimizer
device = torch.device("cpu")
model = ViTAutoEnc(
    in_channels=1,
    img_size=(32, 32, 32),
    patch_size=(16, 16, 16),
    proj_type="conv",
    hidden_size=768,
    mlp_dim=3072,
)

model = model.to(device)

# Define Hyper-paramters for training loop
max_epochs = 100
val_interval = 2
batch_size = 4
lr = 1e-4
epoch_loss_values = []
step_loss_values = []
epoch_cl_loss_values = []
epoch_recon_loss_values = []
val_loss_values = []
best_val_loss = 1000.0

recon_loss = L1Loss()
contrastive_loss = ContrastiveLoss(temperature=0.05)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)


# Define DataLoader using MONAI, CacheDataset needs to be used
train_ds = Dataset(data=train_data, transform=train_transforms)
train_loader = DataLoader(
    train_ds, batch_size=batch_size, shuffle=True, num_workers=4)

val_ds = Dataset(data=val_data, transform=train_transforms)
val_loader = DataLoader(val_ds, batch_size=batch_size,
                        shuffle=True, num_workers=1)

# %%
for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    epoch_cl_loss = 0
    epoch_recon_loss = 0
    step = 0

    for batch_data in train_loader:
        step += 1
        start_time = time.time()

        inputs, inputs_2, gt_input = (
            batch_data["image"].to(device),
            batch_data["image_2"].to(device),
            batch_data["gt_image"].to(device),
        )
        optimizer.zero_grad()
        outputs_v1, hidden_v1 = model(inputs)
        outputs_v2, hidden_v2 = model(inputs_2)

        flat_out_v1 = outputs_v1.flatten(start_dim=1, end_dim=4)
        flat_out_v2 = outputs_v2.flatten(start_dim=1, end_dim=4)

        r_loss = recon_loss(outputs_v1, gt_input)
        cl_loss = contrastive_loss(flat_out_v1, flat_out_v2)

        # Adjust the CL loss by Recon Loss
        total_loss = r_loss + cl_loss * r_loss

        total_loss.backward()
        optimizer.step()
        epoch_loss += total_loss.item()
        step_loss_values.append(total_loss.item())

        # CL & Recon Loss Storage of Value
        epoch_cl_loss += cl_loss.item()
        epoch_recon_loss += r_loss.item()

        end_time = time.time()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}, "
            f"train_loss: {total_loss.item():.4f}, "
            f"time taken: {end_time-start_time}s"
        )

    epoch_loss /= step
    epoch_cl_loss /= step
    epoch_recon_loss /= step

    epoch_loss_values.append(epoch_loss)
    epoch_cl_loss_values.append(epoch_cl_loss)
    epoch_recon_loss_values.append(epoch_recon_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if epoch % val_interval == 0:
        print("Entering Validation for epoch: {}".format(epoch + 1))
        total_val_loss = 0
        val_step = 0
        model.eval()
        for val_batch in val_loader:
            val_step += 1
            start_time = time.time()
            inputs, gt_input = (
                val_batch["image"].to(device),
                val_batch["gt_image"].to(device),
            )
            print("Input shape: {}".format(inputs.shape))
            outputs, outputs_v2 = model(inputs)
            val_loss = recon_loss(outputs, gt_input)
            total_val_loss += val_loss.item()
            end_time = time.time()

        total_val_loss /= val_step
        val_loss_values.append(total_val_loss)
        print(
            f"epoch {epoch + 1} Validation avg loss: {total_val_loss:.4f}, " f"time taken: {end_time-start_time}s")

        if total_val_loss < best_val_loss:
            print(
                f"Saving new model based on validation loss {total_val_loss:.4f}")
            best_val_loss = total_val_loss
            checkpoint = {"epoch": max_epochs, "state_dict": model.state_dict(
            ), "optimizer": optimizer.state_dict()}
            torch.save(checkpoint, os.path.join(logdir_path, "best_model_32.pt"))

        plt.figure(1, figsize=(8, 8))
        plt.subplot(2, 2, 1)
        plt.plot(epoch_loss_values)
        plt.grid()
        plt.title("Training Loss")

        plt.subplot(2, 2, 2)
        plt.plot(val_loss_values)
        plt.grid()
        plt.title("Validation Loss")

        plt.subplot(2, 2, 3)
        plt.plot(epoch_cl_loss_values)
        plt.grid()
        plt.title("Training Contrastive Loss")

        plt.subplot(2, 2, 4)
        plt.plot(epoch_recon_loss_values)
        plt.grid()
        plt.title("Training Recon Loss")

        plt.savefig(os.path.join(logdir_path, "loss_plots.png"))
        plt.close(1)

print("Done")
# Out:
# ----------
# epoch 1/100
# 1/130, train_loss: 1.0361, time taken: 2.914113759994507s
# 2/130, train_loss: 0.8577, time taken: 0.9740486145019531s
# 3/130, train_loss: 0.7127, time taken: 0.887160062789917s
# 4/130, train_loss: 0.8338, time taken: 0.8886680603027344s
# 5/130, train_loss: 0.7300, time taken: 0.7869091033935547s
# 6/130, train_loss: 0.7450, time taken: 0.6051368713378906s
# 7/130, train_loss: 0.7372, time taken: 1.8034999370574951s
# 8/130, train_loss: 0.6568, time taken: 0.9007139205932617s
# 9/130, train_loss: 1.0088, time taken: 1.3712882995605469s
# 10/130, train_loss: 0.6792, time taken: 0.9545109272003174s
# 11/130, train_loss: 0.9428, time taken: 0.8415629863739014s
# 12/130, train_loss: 0.5523, time taken: 0.858116865158081s
# 13/130, train_loss: 0.7515, time taken: 0.7572906017303467s
# 14/130, train_loss: 0.7768, time taken: 0.7852821350097656s
# 15/130, train_loss: 0.6727, time taken: 0.7954914569854736s
# 16/130, train_loss: 0.8000, time taken: 0.8133792877197266s
# 17/130, train_loss: 0.7617, time taken: 0.6268963813781738s
# 18/130, train_loss: 0.5660, time taken: 0.7553746700286865s
# 19/130, train_loss: 0.8031, time taken: 0.8376801013946533s
# 20/130, train_loss: 0.7430, time taken: 0.7294521331787109s
# 21/130, train_loss: 0.7196, time taken: 0.8040299415588379s
# 22/130, train_loss: 0.6570, time taken: 0.7669670581817627s
# 23/130, train_loss: 0.7936, time taken: 0.7426345348358154s
# 24/130, train_loss: 0.6345, time taken: 0.8738448619842529s
# 25/130, train_loss: 0.7136, time taken: 0.626039981842041s
# 26/130, train_loss: 0.8498, time taken: 0.7036275863647461s
# 27/130, train_loss: 0.6740, time taken: 0.7695357799530029s
# 28/130, train_loss: 0.8834, time taken: 2.997527599334717s
# 29/130, train_loss: 0.5954, time taken: 0.696861743927002s
# 30/130, train_loss: 0.7994, time taken: 0.7025034427642822s
# 31/130, train_loss: 1.1553, time taken: 0.6165604591369629s
# 32/130, train_loss: 0.5991, time taken: 0.7724118232727051s
# 33/130, train_loss: 0.6823, time taken: 0.7861127853393555s
# 34/130, train_loss: 0.6949, time taken: 0.7953667640686035s
# 35/130, train_loss: 0.8573, time taken: 0.8006737232208252s
# 36/130, train_loss: 0.6283, time taken: 0.8005893230438232s
# 37/130, train_loss: 0.8508, time taken: 0.745354175567627s
# 38/130, train_loss: 0.7319, time taken: 0.7250087261199951s
# 39/130, train_loss: 0.5064, time taken: 0.7747941017150879s
# 40/130, train_loss: 0.7853, time taken: 0.7882881164550781s
# 41/130, train_loss: 0.8816, time taken: 0.746727466583252s
# 42/130, train_loss: 0.6523, time taken: 0.8119614124298096s
# 43/130, train_loss: 0.5880, time taken: 0.781914234161377s
# 44/130, train_loss: 0.9597, time taken: 0.81209397315979s
# 45/130, train_loss: 0.5123, time taken: 0.699329137802124s
# 46/130, train_loss: 0.7891, time taken: 0.6325123310089111s
# 47/130, train_loss: 0.7821, time taken: 0.7079434394836426s
# 48/130, train_loss: 0.6490, time taken: 0.769803524017334s
# 49/130, train_loss: 0.4908, time taken: 0.6028997898101807s
# 50/130, train_loss: 0.6485, time taken: 0.6184070110321045s
# 51/130, train_loss: 0.4131, time taken: 0.685915470123291s
# 52/130, train_loss: 0.5286, time taken: 0.7293980121612549s
# 53/130, train_loss: 0.9052, time taken: 0.7451257705688477s
# 54/130, train_loss: 0.7528, time taken: 0.8054187297821045s
# 55/130, train_loss: 0.6033, time taken: 0.8015530109405518s
# 56/130, train_loss: 0.8969, time taken: 0.8184444904327393s
# 57/130, train_loss: 0.6547, time taken: 0.633338451385498s
# 58/130, train_loss: 0.5508, time taken: 0.6851234436035156s
# 59/130, train_loss: 0.7339, time taken: 0.9103925228118896s
# 60/130, train_loss: 0.8183, time taken: 0.6838328838348389s
# 61/130, train_loss: 0.8411, time taken: 0.6937470436096191s
# 62/130, train_loss: 0.7359, time taken: 0.6886117458343506s
# 63/130, train_loss: 0.4848, time taken: 0.6960277557373047s
# 64/130, train_loss: 0.7078, time taken: 0.7212662696838379s
# 65/130, train_loss: 0.5535, time taken: 0.641303539276123s
# 66/130, train_loss: 0.6478, time taken: 0.6571624279022217s
# 67/130, train_loss: 0.7252, time taken: 0.7638905048370361s
# 68/130, train_loss: 0.6157, time taken: 0.8244268894195557s
# 69/130, train_loss: 0.7092, time taken: 0.8299076557159424s
# 70/130, train_loss: 0.9538, time taken: 0.836949348449707s
# 71/130, train_loss: 0.7336, time taken: 0.795961856842041s
# 72/130, train_loss: 0.7057, time taken: 1.8016910552978516s
# 73/130, train_loss: 0.9023, time taken: 0.7921421527862549s
# 74/130, train_loss: 0.9049, time taken: 0.6468076705932617s
# 75/130, train_loss: 0.8576, time taken: 0.7090907096862793s
# 76/130, train_loss: 0.7223, time taken: 0.6830077171325684s
# 77/130, train_loss: 0.7214, time taken: 0.6809597015380859s
# 78/130, train_loss: 0.7629, time taken: 0.6411864757537842s
# 79/130, train_loss: 0.7672, time taken: 0.7363934516906738s
# 80/130, train_loss: 0.6809, time taken: 0.7053163051605225s
# 81/130, train_loss: 0.4668, time taken: 0.7186520099639893s
# 82/130, train_loss: 0.7349, time taken: 0.7727642059326172s
# 83/130, train_loss: 0.7044, time taken: 0.7370378971099854s
# 84/130, train_loss: 0.8102, time taken: 0.8009531497955322s
# 85/130, train_loss: 0.6690, time taken: 0.7942209243774414s
# 86/130, train_loss: 0.9405, time taken: 0.7708508968353271s
# 87/130, train_loss: 0.5763, time taken: 0.6974115371704102s
# 88/130, train_loss: 0.5768, time taken: 0.7795050144195557s
# 89/130, train_loss: 0.6647, time taken: 0.8056726455688477s
# 90/130, train_loss: 0.6725, time taken: 0.792170524597168s
# 91/130, train_loss: 0.4484, time taken: 0.743351936340332s
# 92/130, train_loss: 0.7599, time taken: 0.7293438911437988s
# 93/130, train_loss: 0.6293, time taken: 0.7028117179870605s
# 94/130, train_loss: 0.9571, time taken: 0.8090107440948486s
# 95/130, train_loss: 0.5473, time taken: 0.7677195072174072s
# 96/130, train_loss: 0.6039, time taken: 0.7455103397369385s
# 97/130, train_loss: 0.8819, time taken: 0.8118641376495361s
# 98/130, train_loss: 0.6301, time taken: 0.8686184883117676s
# 99/130, train_loss: 0.5640, time taken: 0.7178084850311279s
# 100/130, train_loss: 0.5934, time taken: 0.7805752754211426s
# 101/130, train_loss: 0.8443, time taken: 0.6165890693664551s
# 102/130, train_loss: 0.7346, time taken: 0.7795650959014893s
# 103/130, train_loss: 0.5397, time taken: 0.694648265838623s
# 104/130, train_loss: 0.7063, time taken: 0.7903869152069092s
# 105/130, train_loss: 0.8440, time taken: 0.8056368827819824s
# 106/130, train_loss: 0.8360, time taken: 0.8833837509155273s
# 107/130, train_loss: 0.6687, time taken: 0.7217185497283936s
# 108/130, train_loss: 0.8224, time taken: 0.7856924533843994s
# 109/130, train_loss: 0.6085, time taken: 0.698960542678833s
# 110/130, train_loss: 0.4830, time taken: 0.6975307464599609s
# 111/130, train_loss: 0.4974, time taken: 0.6021997928619385s
# 112/130, train_loss: 0.4863, time taken: 0.7959508895874023s
# 113/130, train_loss: 0.8410, time taken: 0.7889606952667236s
# 114/130, train_loss: 0.6983, time taken: 0.7987189292907715s
# 115/130, train_loss: 0.5477, time taken: 0.7895433902740479s
# 116/130, train_loss: 0.7179, time taken: 0.7874717712402344s
# 117/130, train_loss: 0.7279, time taken: 0.8037045001983643s
# 118/130, train_loss: 0.7385, time taken: 0.7891526222229004s
# 119/130, train_loss: 0.8231, time taken: 0.8624494075775146s
# 120/130, train_loss: 0.7433, time taken: 0.7940123081207275s
# 121/130, train_loss: 0.7525, time taken: 1.0894856452941895s
# 122/130, train_loss: 0.4582, time taken: 1.0201935768127441s
# 123/130, train_loss: 0.7652, time taken: 0.9933042526245117s
# 124/130, train_loss: 0.8269, time taken: 0.8901777267456055s
# 125/130, train_loss: 0.7696, time taken: 0.801349401473999s
# 126/130, train_loss: 0.7251, time taken: 0.8638715744018555s
# 127/130, train_loss: 0.7792, time taken: 0.8810172080993652s
# 128/130, train_loss: 0.6471, time taken: 0.7396860122680664s
# 129/130, train_loss: 0.8323, time taken: 0.666661262512207s
# 130/130, train_loss: 0.4719, time taken: 0.6316862106323242s
# epoch 1 average loss: 0.7161
# Entering Validation for epoch: 1
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([8, 1, 32, 32, 32])
# Input shape: torch.Size([4, 1, 32, 32, 32])
# epoch 1 Validation avg loss: 0.1998, time taken: 0.13185715675354004s
# Saving new model based on validation loss 0.1998
# ----------
# epoch 2/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 21
#      19 optimizer.zero_grad()
#      20 outputs_v1, hidden_v1 = model(inputs)
# ---> 21 outputs_v2, hidden_v2 = model(inputs_2)
#      23 flat_out_v1 = outputs_v1.flatten(start_dim=1, end_dim=4)
#      24 flat_out_v2 = outputs_v2.flatten(start_dim=1, end_dim=4)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/monai/networks/nets/vitautoenc.py:134, in ViTAutoEnc.forward(self, x)
#     132 hidden_states_out = []
#     133 for blk in self.blocks:
# --> 134     x = blk(x)
#     135     hidden_states_out.append(x)
#     136 x = self.norm(x)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/monai/networks/blocks/transformerblock.py:60, in TransformerBlock.forward(self, x)
#      59 def forward(self, x):
# ---> 60     x = x + self.attn(self.norm1(x))
#      61     x = x + self.mlp(self.norm2(x))
#      62     return x
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/monai/networks/blocks/selfattention.py:67, in SABlock.forward(self, x)
#      66 def forward(self, x):
# ---> 67     output = self.input_rearrange(self.qkv(x))
#      68     q, k, v = output[0], output[1], output[2]
#      69     att_mat = (torch.einsum("blxd,blyd->blxy", q, k) * self.scale).softmax(dim=-1)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/monai/data/meta_tensor.py:282, in MetaTensor.__torch_function__(cls, func, types, args, kwargs)
#     280 if kwargs is None:
#     281     kwargs = {}
# --> 282 ret = super().__torch_function__(func, types, args, kwargs)
#     283 # if `out` has been used as argument, metadata is not copied, nothing to do.
#     284 # if "out" in kwargs:
#     285 #     return ret
#     286 if _not_requiring_metadata(ret):
#
# File ~/virtenvs/SSLUnet/lib/python3.11/site-packages/torch/_tensor.py:1418, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1415     return NotImplemented
#    1417 with _C.DisableTorchFunctionSubclass():
# -> 1418     ret = func(*args, **kwargs)
#    1419     if func in get_default_nowrap_functions():
#    1420         return ret
#
# KeyboardInterrupt:

# %%
import torch
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
import torch
gpu_available = torch.cuda.is_available()
if gpu_available:
    print("GPU is available.")
else:
    print("GPU is not available. Using CPU for computation.")
# Out:
# GPU is available.
